# %% [markdown]
# # Load dataset From Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Dataset.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Dataset/51/image_01381.jpg
#   inflating: /content/Dataset/51/image_01382.jpg
#   inflating: /content/Dataset/51/image_01383.jpg
#   inflating: /content/Dataset/51/image_01384.jpg
#   inflating: /content/Dataset/51/image_01385.jpg
#   inflating: /content/Dataset/51/image_01386.jpg
#   inflating: /content/Dataset/51/image_01387.jpg
#   inflating: /content/Dataset/51/image_01388.jpg
#   inflating: /content/Dataset/51/image_01389.jpg
#   inflating: /content/Dataset/51/image_01390.jpg
#   inflating: /content/Dataset/51/image_01391.jpg
#   inflating: /content/Dataset/51/image_01392.jpg
#   inflating: /content/Dataset/51/image_01393.jpg
#   inflating: /content/Dataset/51/image_01394.jpg
#   inflating: /content/Dataset/51/image_01395.jpg
#   inflating: /content/Dataset/51/image_01396.jpg
#   inflating: /content/Dataset/51/image_01397.jpg
#   inflating: /content/Dataset/51/image_01398.jpg
#   inflating: /content/Dataset/51/image_01399.jpg
#   inflating: /content/Dataset/51/image_01400.jpg
#   inflating: /content/Dataset/51/image_01401.jpg
#   inflating: /content/Dataset/51/image_01402.jpg
#   inflating: /content/Dataset/51/image_01403.jpg
#   inflating: /content/Dataset/51/image_01404.jpg
#   inflating: /content/Dataset/51/image_01405.jpg
#   inflating: /content/Dataset/51/image_01406.jpg
#   inflating: /content/Dataset/51/image_01407.jpg
#   inflating: /content/Dataset/51/image_01408.jpg
#   inflating: /content/Dataset/51/image_01409.jpg
#   inflating: /content/Dataset/51/image_01410.jpg
#   inflating: /content/Dataset/51/image_01411.jpg
#   inflating: /content/Dataset/51/image_01412.jpg
#   inflating: /content/Dataset/51/image_01413.jpg
#   inflating: /content/Dataset/51/image_01414.jpg
#   inflating: /content/Dataset/51/image_01415.jpg
#   inflating: /content/Dataset/51/image_01416.jpg
#   inflating: /content/Dataset/51/image_01417.jpg
#   inflating: /content/Dataset/51/image_01418.jpg
#   inflating: /content/Dataset/51/image_01419.jpg
#   inflating: /content/Dataset/51/image_01420.jpg
#   inflating: /content/Dataset/51/image_01421.jpg
#   inflating: /content/Dataset/51/image_01422.jpg
#   inflating: /content/Dataset/51/image_01423.jpg
#   inflating: /content/Dataset/51/image_01424.jpg
#   inflating: /content/Dataset/51/image_01425.jpg
#   inflating: /content/Dataset/51/image_01426.jpg
#   inflating: /content/Dataset/51/image_01427.jpg
#   inflating: /content/Dataset/51/image_01428.jpg
#   inflating: /content/Dataset/51/image_01429.jpg
#   inflating: /content/Dataset/51/image_01430.jpg
#   inflating: /content/Dataset/51/image_01431.jpg
#   inflating: /content/Dataset/51/image_01432.jpg
#   inflating: /content/Dataset/51/image_01433.jpg
#   inflating: /content/Dataset/51/image_01434.jpg
#   inflating: /content/Dataset/51/image_01435.jpg
#   inflating: /content/Dataset/51/image_01436.jpg
#   inflating: /content/Dataset/51/image_01437.jpg
#   inflating: /content/Dataset/51/image_01438.jpg
#   inflating: /content/Dataset/51/image_01439.jpg
#   inflating: /content/Dataset/51/image_01440.jpg
#   inflating: /content/Dataset/51/image_01441.jpg
#   inflating: /content/Dataset/51/image_01442.jpg
#   inflating: /content/Dataset/51/image_01443.jpg
#   inflating: /content/Dataset/51/image_01444.jpg
#   inflating: /content/Dataset/51/image_01445.jpg
#   inflating: /content/Dataset/51/image_01446.jpg
#   inflating: /content/Dataset/51/image_01447.jpg
#   inflating: /content/Dataset/51/image_01448.jpg
#   inflating: /content/Dataset/51/image_01449.jpg
#   inflating: /content/Dataset/51/image_01450.jpg
#   inflating: /content/Dataset/51/image_01451.jpg
#   inflating: /content/Dataset/51/image_01452.jpg
#   inflating: /content/Dataset/51/image_01453.jpg
#   inflating: /content/Dataset/51/image_01454.jpg
#   inflating: /content/Dataset/51/image_01455.jpg
#   inflating: /content/Dataset/51/image_01456.jpg
#   inflating: /content/Dataset/51/image_01457.jpg
#   inflating: /content/Dataset/51/image_01458.jpg
#   inflating: /content/Dataset/51/image_01459.jpg
#   inflating: /content/Dataset/51/image_01460.jpg
#   inflating: /content/Dataset/51/image_01461.jpg
#   inflating: /content/Dataset/51/image_01462.jpg
#   inflating: /content/Dataset/51/image_01463.jpg
#   inflating: /content/Dataset/51/image_01464.jpg
#   inflating: /content/Dataset/51/image_01465.jpg
#   inflating: /content/Dataset/51/image_01466.jpg
#   inflating: /content/Dataset/51/image_01467.jpg
#   inflating: /content/Dataset/51/image_01468.jpg
#   inflating: /content/Dataset/51/image_01469.jpg
#   inflating: /content/Dataset/51/image_01470.jpg
#   inflating: /content/Dataset/51/image_01471.jpg
#   inflating: /content/Dataset/51/image_01472.jpg
#   inflating: /content/Dataset/51/image_01473.jpg
#   inflating: /content/Dataset/51/image_01474.jpg
#   inflating: /content/Dataset/51/image_01475.jpg
#   inflating: /content/Dataset/51/image_01476.jpg
#   inflating: /content/Dataset/51/image_01477.jpg
#   inflating: /content/Dataset/51/image_01478.jpg
#   inflating: /content/Dataset/51/image_01479.jpg
#   inflating: /content/Dataset/51/image_01480.jpg
#   inflating: /content/Dataset/51/image_01481.jpg
#   inflating: /content/Dataset/51/image_01482.jpg
#   inflating: /content/Dataset/51/image_01483.jpg
#   inflating: /content/Dataset/51/image_01484.jpg
#   inflating: /content/Dataset/51/image_01485.jpg
#   inflating: /content/Dataset/51/image_01486.jpg
#   inflating: /content/Dataset/51/image_01487.jpg
#   inflating: /content/Dataset/51/image_01488.jpg
#   inflating: /content/Dataset/51/image_01489.jpg
#   inflating: /content/Dataset/51/image_01490.jpg
#   inflating: /content/Dataset/51/image_03913.jpg
#   inflating: /content/Dataset/51/image_03914.jpg
#   inflating: /content/Dataset/51/image_03915.jpg
#   inflating: /content/Dataset/51/image_03916.jpg
#   inflating: /content/Dataset/51/image_03917.jpg
#   inflating: /content/Dataset/51/image_03918.jpg
#   inflating: /content/Dataset/51/image_03919.jpg
#   inflating: /content/Dataset/51/image_03920.jpg
#   inflating: /content/Dataset/51/image_03921.jpg
#   inflating: /content/Dataset/51/image_03922.jpg
#   inflating: /content/Dataset/51/image_03923.jpg
#   inflating: /content/Dataset/51/image_03924.jpg
#   inflating: /content/Dataset/51/image_03925.jpg
#   inflating: /content/Dataset/51/image_03926.jpg
#   inflating: /content/Dataset/51/image_03927.jpg
#   inflating: /content/Dataset/51/image_03928.jpg
#   inflating: /content/Dataset/51/image_03929.jpg
#   inflating: /content/Dataset/51/image_03930.jpg
#   inflating: /content/Dataset/51/image_03931.jpg
#   inflating: /content/Dataset/51/image_03932.jpg
#   inflating: /content/Dataset/51/image_03933.jpg
#   inflating: /content/Dataset/51/image_03934.jpg
#   inflating: /content/Dataset/51/image_03935.jpg
#   inflating: /content/Dataset/51/image_03936.jpg
#   inflating: /content/Dataset/51/image_03937.jpg
#   inflating: /content/Dataset/51/image_03938.jpg
#   inflating: /content/Dataset/51/image_03939.jpg
#   inflating: /content/Dataset/51/image_03940.jpg
#   inflating: /content/Dataset/51/image_03941.jpg
#   inflating: /content/Dataset/51/image_03942.jpg
#   inflating: /content/Dataset/51/image_03943.jpg
#   inflating: /content/Dataset/51/image_03944.jpg
#   inflating: /content/Dataset/51/image_03945.jpg
#   inflating: /content/Dataset/51/image_03946.jpg
#   inflating: /content/Dataset/51/image_03947.jpg
#   inflating: /content/Dataset/51/image_03948.jpg
#   inflating: /content/Dataset/51/image_03949.jpg
#   inflating: /content/Dataset/51/image_03950.jpg
#   inflating: /content/Dataset/51/image_03951.jpg
#   inflating: /content/Dataset/51/image_03952.jpg
#   inflating: /content/Dataset/51/image_03953.jpg
#   inflating: /content/Dataset/51/image_03954.jpg
#   inflating: /content/Dataset/51/image_03955.jpg
#   inflating: /content/Dataset/51/image_03956.jpg
#   inflating: /content/Dataset/51/image_03957.jpg
#   inflating: /content/Dataset/51/image_03958.jpg
#   inflating: /content/Dataset/51/image_03959.jpg
#   inflating: /content/Dataset/51/image_03960.jpg
#   inflating: /content/Dataset/51/image_03961.jpg
#   inflating: /content/Dataset/51/image_03962.jpg
#   inflating: /content/Dataset/51/image_03963.jpg
#   inflating: /content/Dataset/51/image_03964.jpg
#   inflating: /content/Dataset/51/image_03965.jpg
#   inflating: /content/Dataset/51/image_03966.jpg
#   inflating: /content/Dataset/51/image_03967.jpg
#   inflating: /content/Dataset/51/image_03968.jpg
#   inflating: /content/Dataset/51/image_03969.jpg
#   inflating: /content/Dataset/51/image_03970.jpg
#   inflating: /content/Dataset/51/image_03971.jpg
#   inflating: /content/Dataset/51/image_03972.jpg
#   inflating: /content/Dataset/51/image_03973.jpg
#   inflating: /content/Dataset/51/image_03974.jpg
#   inflating: /content/Dataset/51/image_03975.jpg
#   inflating: /content/Dataset/51/image_03976.jpg
#   inflating: /content/Dataset/51/image_03977.jpg
#   inflating: /content/Dataset/51/image_03978.jpg
#   inflating: /content/Dataset/51/image_03979.jpg
#   inflating: /content/Dataset/51/image_03980.jpg
#   inflating: /content/Dataset/51/image_03981.jpg
#   inflating: /content/Dataset/51/image_03982.jpg
#   inflating: /content/Dataset/51/image_03983.jpg
#   inflating: /content/Dataset/51/image_03984.jpg
#   inflating: /content/Dataset/51/image_03985.jpg
#   inflating: /content/Dataset/51/image_03986.jpg
#   inflating: /content/Dataset/51/image_03987.jpg
#   inflating: /content/Dataset/51/image_03988.jpg
#   inflating: /content/Dataset/51/image_03989.jpg
#   inflating: /content/Dataset/51/image_03990.jpg
#   inflating: /content/Dataset/51/image_03991.jpg
#   inflating: /content/Dataset/51/image_03992.jpg
#   inflating: /content/Dataset/51/image_03993.jpg
#    creating: /content/Dataset/52/
#   inflating: /content/Dataset/52/image_04159.jpg
#   inflating: /content/Dataset/52/image_04160.jpg
#   inflating: /content/Dataset/52/image_04161.jpg
#   inflating: /content/Dataset/52/image_04162.jpg
#   inflating: /content/Dataset/52/image_04163.jpg
#   inflating: /content/Dataset/52/image_04164.jpg
#   inflating: /content/Dataset/52/image_04165.jpg
#   inflating: /content/Dataset/52/image_04166.jpg
#   inflating: /content/Dataset/52/image_04167.jpg
#   inflating: /content/Dataset/52/image_04168.jpg
#   inflating: /content/Dataset/52/image_04169.jpg
#   inflating: /content/Dataset/52/image_04170.jpg
#   inflating: /content/Dataset/52/image_04171.jpg
#   inflating: /content/Dataset/52/image_04172.jpg
#   inflating: /content/Dataset/52/image_04173.jpg
#   inflating: /content/Dataset/52/image_04174.jpg
#   inflating: /content/Dataset/52/image_04175.jpg
#   inflating: /content/Dataset/52/image_04176.jpg
#   inflating: /content/Dataset/52/image_04177.jpg
#   inflating: /content/Dataset/52/image_04178.jpg
#   inflating: /content/Dataset/52/image_04179.jpg
#   inflating: /content/Dataset/52/image_04180.jpg
#   inflating: /content/Dataset/52/image_04181.jpg
#   inflating: /content/Dataset/52/image_04182.jpg
#   inflating: /content/Dataset/52/image_04183.jpg
#   inflating: /content/Dataset/52/image_04184.jpg
#   inflating: /content/Dataset/52/image_04185.jpg
#   inflating: /content/Dataset/52/image_04186.jpg
#   inflating: /content/Dataset/52/image_04187.jpg
#   inflating: /content/Dataset/52/image_04188.jpg
#   inflating: /content/Dataset/52/image_04189.jpg
#   inflating: /content/Dataset/52/image_04190.jpg
#   inflating: /content/Dataset/52/image_04191.jpg
#   inflating: /content/Dataset/52/image_04192.jpg
#   inflating: /content/Dataset/52/image_04193.jpg
#   inflating: /content/Dataset/52/image_04194.jpg
#   inflating: /content/Dataset/52/image_04195.jpg
#   inflating: /content/Dataset/52/image_04196.jpg
#   inflating: /content/Dataset/52/image_04197.jpg
#   inflating: /content/Dataset/52/image_04198.jpg
#   inflating: /content/Dataset/52/image_04199.jpg
#   inflating: /content/Dataset/52/image_04200.jpg
#   inflating: /content/Dataset/52/image_04201.jpg
#   inflating: /content/Dataset/52/image_04202.jpg
#   inflating: /content/Dataset/52/image_04203.jpg
#   inflating: /content/Dataset/52/image_04204.jpg
#   inflating: /content/Dataset/52/image_04205.jpg
#   inflating: /content/Dataset/52/image_04206.jpg
#   inflating: /content/Dataset/52/image_04207.jpg
#   inflating: /content/Dataset/52/image_04208.jpg
#   inflating: /content/Dataset/52/image_04209.jpg
#   inflating: /content/Dataset/52/image_04210.jpg
#   inflating: /content/Dataset/52/image_04211.jpg
#   inflating: /content/Dataset/52/image_04212.jpg
#   inflating: /content/Dataset/52/image_04213.jpg
#   inflating: /content/Dataset/52/image_04214.jpg
#   inflating: /content/Dataset/52/image_04215.jpg
#   inflating: /content/Dataset/52/image_04216.jpg
#   inflating: /content/Dataset/52/image_04217.jpg
#   inflating: /content/Dataset/52/image_04218.jpg
#   inflating: /content/Dataset/52/image_04219.jpg
#   inflating: /content/Dataset/52/image_04220.jpg
#   inflating: /content/Dataset/52/image_04221.jpg
#   inflating: /content/Dataset/52/image_04222.jpg
#   inflating: /content/Dataset/52/image_04223.jpg
#   inflating: /content/Dataset/52/image_04224.jpg
#   inflating: /content/Dataset/52/image_04225.jpg
#   inflating: /content/Dataset/52/image_04226.jpg
#   inflating: /content/Dataset/52/image_04227.jpg
#   inflating: /content/Dataset/52/image_04228.jpg
#   inflating: /content/Dataset/52/image_04229.jpg
#   inflating: /content/Dataset/52/image_04230.jpg
#   inflating: /content/Dataset/52/image_04231.jpg
#   inflating: /content/Dataset/52/image_04232.jpg
#   inflating: /content/Dataset/52/image_04233.jpg
#   inflating: /content/Dataset/52/image_04234.jpg
#   inflating: /content/Dataset/52/image_04235.jpg
#   inflating: /content/Dataset/52/image_04236.jpg
#   inflating: /content/Dataset/52/image_04237.jpg
#   inflating: /content/Dataset/52/image_04238.jpg
#   inflating: /content/Dataset/52/image_04239.jpg
#   inflating: /content/Dataset/52/image_04240.jpg
#   inflating: /content/Dataset/52/image_04241.jpg
#   inflating: /content/Dataset/52/image_04242.jpg
#   inflating: /content/Dataset/52/image_04243.jpg
#    creating: /content/Dataset/53/
#   inflating: /content/Dataset/53/image_03641.jpg
#   inflating: /content/Dataset/53/image_03642.jpg
#   inflating: /content/Dataset/53/image_03643.jpg
#   inflating: /content/Dataset/53/image_03644.jpg
#   inflating: /content/Dataset/53/image_03645.jpg
#   inflating: /content/Dataset/53/image_03646.jpg
#   inflating: /content/Dataset/53/image_03647.jpg
#   inflating: /content/Dataset/53/image_03648.jpg
#   inflating: /content/Dataset/53/image_03649.jpg
#   inflating: /content/Dataset/53/image_03650.jpg
#   inflating: /content/Dataset/53/image_03651.jpg
#   inflating: /content/Dataset/53/image_03652.jpg
#   inflating: /content/Dataset/53/image_03653.jpg
#   inflating: /content/Dataset/53/image_03654.jpg
#   inflating: /content/Dataset/53/image_03655.jpg
#   inflating: /content/Dataset/53/image_03656.jpg
#   inflating: /content/Dataset/53/image_03657.jpg
#   inflating: /content/Dataset/53/image_03658.jpg
#   inflating: /content/Dataset/53/image_03659.jpg
#   inflating: /content/Dataset/53/image_03660.jpg
#   inflating: /content/Dataset/53/image_03661.jpg
#   inflating: /content/Dataset/53/image_03662.jpg
#   inflating: /content/Dataset/53/image_03663.jpg
#   inflating: /content/Dataset/53/image_03664.jpg
#   inflating: /content/Dataset/53/image_03665.jpg
#   inflating: /content/Dataset/53/image_03666.jpg
#   inflating: /content/Dataset/53/image_03667.jpg
#   inflating: /content/Dataset/53/image_03668.jpg
#   inflating: /content/Dataset/53/image_03669.jpg
#   inflating: /content/Dataset/53/image_03670.jpg
#   inflating: /content/Dataset/53/image_03671.jpg
#   inflating: /content/Dataset/53/image_03672.jpg
#   inflating: /content/Dataset/53/image_03673.jpg
#   inflating: /content/Dataset/53/image_03674.jpg
#   inflating: /content/Dataset/53/image_03675.jpg
#   inflating: /content/Dataset/53/image_03676.jpg
#   inflating: /content/Dataset/53/image_03677.jpg
#   inflating: /content/Dataset/53/image_03678.jpg
#   inflating: /content/Dataset/53/image_03679.jpg
#   inflating: /content/Dataset/53/image_03680.jpg
#   inflating: /content/Dataset/53/image_03681.jpg
#   inflating: /content/Dataset/53/image_03682.jpg
#   inflating: /content/Dataset/53/image_03683.jpg
#   inflating: /content/Dataset/53/image_03684.jpg
#   inflating: /content/Dataset/53/image_03685.jpg
#   inflating: /content/Dataset/53/image_03686.jpg
#   inflating: /content/Dataset/53/image_03687.jpg
#   inflating: /content/Dataset/53/image_03688.jpg
#   inflating: /content/Dataset/53/image_03689.jpg
#   inflating: /content/Dataset/53/image_03690.jpg
#   inflating: /content/Dataset/53/image_03691.jpg
#   inflating: /content/Dataset/53/image_03692.jpg
#   inflating: /content/Dataset/53/image_03693.jpg
#   inflating: /content/Dataset/53/image_03694.jpg
#   inflating: /content/Dataset/53/image_03695.jpg
#   inflating: /content/Dataset/53/image_03696.jpg
#   inflating: /content/Dataset/53/image_03697.jpg
#   inflating: /content/Dataset/53/image_03698.jpg
#   inflating: /content/Dataset/53/image_03699.jpg
#   inflating: /content/Dataset/53/image_03700.jpg
#   inflating: /content/Dataset/53/image_03701.jpg
#   inflating: /content/Dataset/53/image_03702.jpg
#   inflating: /content/Dataset/53/image_03703.jpg
#   inflating: /content/Dataset/53/image_03704.jpg
#   inflating: /content/Dataset/53/image_03705.jpg
#   inflating: /content/Dataset/53/image_03706.jpg
#   inflating: /content/Dataset/53/image_03707.jpg
#   inflating: /content/Dataset/53/image_03708.jpg
#   inflating: /content/Dataset/53/image_03709.jpg
#   inflating: /content/Dataset/53/image_03710.jpg
#   inflating: /content/Dataset/53/image_03711.jpg
#   inflating: /content/Dataset/53/image_03712.jpg
#   inflating: /content/Dataset/53/image_03713.jpg
#   inflating: /content/Dataset/53/image_03714.jpg
#   inflating: /content/Dataset/53/image_03715.jpg
#   inflating: /content/Dataset/53/image_03716.jpg
#   inflating: /content/Dataset/53/image_03717.jpg
#   inflating: /content/Dataset/53/image_03718.jpg
#   inflating: /content/Dataset/53/image_03719.jpg
#   inflating: /content/Dataset/53/image_03720.jpg
#   inflating: /content/Dataset/53/image_03721.jpg
#   inflating: /content/Dataset/53/image_03722.jpg
#   inflating: /content/Dataset/53/image_03723.jpg
#   inflating: /content/Dataset/53/image_03724.jpg
#   inflating: /content/Dataset/53/image_03725.jpg
#   inflating: /content/Dataset/53/image_03726.jpg
#   inflating: /content/Dataset/53/image_03727.jpg
#   inflating: /content/Dataset/53/image_03728.jpg
#   inflating: /content/Dataset/53/image_03729.jpg
#   inflating: /content/Dataset/53/image_03730.jpg
#   inflating: /content/Dataset/53/image_03731.jpg
#   inflating: /content/Dataset/53/image_03732.jpg
#   inflating: /content/Dataset/53/image_03733.jpg
#    creating: /content/Dataset/54/
#   inflating: /content/Dataset/54/image_05399.jpg
#   inflating: /content/Dataset/54/image_05400.jpg
#   inflating: /content/Dataset/54/image_05401.jpg
#   inflating: /content/Dataset/54/image_05402.jpg
#   inflating: /content/Dataset/54/image_05403.jpg
#   inflating: /content/Dataset/54/image_05404.jpg
#   inflating: /content/Dataset/54/image_05405.jpg
#   inflating: /content/Dataset/54/image_05406.jpg
#   inflating: /content/Dataset/54/image_05407.jpg
#   inflating: /content/Dataset/54/image_05408.jpg
#   inflating: /content/Dataset/54/image_05409.jpg
#   inflating: /content/Dataset/54/image_05410.jpg
#   inflating: /content/Dataset/54/image_05411.jpg
#   inflating: /content/Dataset/54/image_05412.jpg
#   inflating: /content/Dataset/54/image_05413.jpg
#   inflating: /content/Dataset/54/image_05414.jpg
#   inflating: /content/Dataset/54/image_05415.jpg
#   inflating: /content/Dataset/54/image_05416.jpg
#   inflating: /content/Dataset/54/image_05417.jpg
#   inflating: /content/Dataset/54/image_05418.jpg
#   inflating: /content/Dataset/54/image_05419.jpg
#   inflating: /content/Dataset/54/image_05420.jpg
#   inflating: /content/Dataset/54/image_05421.jpg
#   inflating: /content/Dataset/54/image_05422.jpg
#   inflating: /content/Dataset/54/image_05423.jpg
#   inflating: /content/Dataset/54/image_05424.jpg
#   inflating: /content/Dataset/54/image_05425.jpg
#   inflating: /content/Dataset/54/image_05426.jpg
#   inflating: /content/Dataset/54/image_05427.jpg
#   inflating: /content/Dataset/54/image_05428.jpg
#   inflating: /content/Dataset/54/image_05429.jpg
#   inflating: /content/Dataset/54/image_05430.jpg
#   inflating: /content/Dataset/54/image_05431.jpg
#   inflating: /content/Dataset/54/image_05432.jpg
#   inflating: /content/Dataset/54/image_05433.jpg
#   inflating: /content/Dataset/54/image_05434.jpg
#   inflating: /content/Dataset/54/image_05435.jpg
#   inflating: /content/Dataset/54/image_05436.jpg
#   inflating: /content/Dataset/54/image_05437.jpg
#   inflating: /content/Dataset/54/image_05438.jpg
#   inflating: /content/Dataset/54/image_05439.jpg
#   inflating: /content/Dataset/54/image_05440.jpg
#   inflating: /content/Dataset/54/image_05441.jpg
#   inflating: /content/Dataset/54/image_05442.jpg
#   inflating: /content/Dataset/54/image_05443.jpg
#   inflating: /content/Dataset/54/image_05444.jpg
#   inflating: /content/Dataset/54/image_05445.jpg
#   inflating: /content/Dataset/54/image_05446.jpg
#   inflating: /content/Dataset/54/image_05447.jpg
#   inflating: /content/Dataset/54/image_05448.jpg
#   inflating: /content/Dataset/54/image_05449.jpg
#   inflating: /content/Dataset/54/image_05450.jpg
#   inflating: /content/Dataset/54/image_05451.jpg
#   inflating: /content/Dataset/54/image_05452.jpg
#   inflating: /content/Dataset/54/image_05453.jpg
#   inflating: /content/Dataset/54/image_05454.jpg
#   inflating: /content/Dataset/54/image_05455.jpg
#   inflating: /content/Dataset/54/image_05456.jpg
#   inflating: /content/Dataset/54/image_05457.jpg
#   inflating: /content/Dataset/54/image_05458.jpg
#   inflating: /content/Dataset/54/image_05459.jpg
#    creating: /content/Dataset/55/
#   inflating: /content/Dataset/55/image_04696.jpg
#   inflating: /content/Dataset/55/image_04697.jpg
#   inflating: /content/Dataset/55/image_04698.jpg
#   inflating: /content/Dataset/55/image_04699.jpg
#   inflating: /content/Dataset/55/image_04700.jpg
#   inflating: /content/Dataset/55/image_04701.jpg
#   inflating: /content/Dataset/55/image_04702.jpg
#   inflating: /content/Dataset/55/image_04703.jpg
#   inflating: /content/Dataset/55/image_04704.jpg
#   inflating: /content/Dataset/55/image_04705.jpg
#   inflating: /content/Dataset/55/image_04706.jpg
#   inflating: /content/Dataset/55/image_04707.jpg
#   inflating: /content/Dataset/55/image_04708.jpg
#   inflating: /content/Dataset/55/image_04709.jpg
#   inflating: /content/Dataset/55/image_04710.jpg
#   inflating: /content/Dataset/55/image_04711.jpg
#   inflating: /content/Dataset/55/image_04712.jpg
#   inflating: /content/Dataset/55/image_04713.jpg
#   inflating: /content/Dataset/55/image_04714.jpg
#   inflating: /content/Dataset/55/image_04715.jpg
#   inflating: /content/Dataset/55/image_04716.jpg
#   inflating: /content/Dataset/55/image_04717.jpg
#   inflating: /content/Dataset/55/image_04718.jpg
#   inflating: /content/Dataset/55/image_04719.jpg
#   inflating: /content/Dataset/55/image_04720.jpg
#   inflating: /content/Dataset/55/image_04721.jpg
#   inflating: /content/Dataset/55/image_04722.jpg
#   inflating: /content/Dataset/55/image_04723.jpg
#   inflating: /content/Dataset/55/image_04724.jpg
#   inflating: /content/Dataset/55/image_04725.jpg
#   inflating: /content/Dataset/55/image_04726.jpg
#   inflating: /content/Dataset/55/image_04727.jpg
#   inflating: /content/Dataset/55/image_04728.jpg
#   inflating: /content/Dataset/55/image_04729.jpg
#   inflating: /content/Dataset/55/image_04730.jpg
#   inflating: /content/Dataset/55/image_04731.jpg
#   inflating: /content/Dataset/55/image_04732.jpg
#   inflating: /content/Dataset/55/image_04733.jpg
#   inflating: /content/Dataset/55/image_04734.jpg
#   inflating: /content/Dataset/55/image_04735.jpg
#   inflating: /content/Dataset/55/image_04736.jpg
#   inflating: /content/Dataset/55/image_04737.jpg
#   inflating: /content/Dataset/55/image_04738.jpg
#   inflating: /content/Dataset/55/image_04739.jpg
#   inflating: /content/Dataset/55/image_04740.jpg
#   inflating: /content/Dataset/55/image_04741.jpg
#   inflating: /content/Dataset/55/image_04742.jpg
#   inflating: /content/Dataset/55/image_04743.jpg
#   inflating: /content/Dataset/55/image_04744.jpg
#   inflating: /content/Dataset/55/image_04745.jpg
#   inflating: /content/Dataset/55/image_04746.jpg
#   inflating: /content/Dataset/55/image_04747.jpg
#   inflating: /content/Dataset/55/image_04748.jpg
#   inflating: /content/Dataset/55/image_04749.jpg
#   inflating: /content/Dataset/55/image_04750.jpg
#   inflating: /content/Dataset/55/image_04751.jpg
#   inflating: /content/Dataset/55/image_04752.jpg
#   inflating: /content/Dataset/55/image_04753.jpg
#   inflating: /content/Dataset/55/image_04754.jpg
#   inflating: /content/Dataset/55/image_04755.jpg
#   inflating: /content/Dataset/55/image_04756.jpg
#   inflating: /content/Dataset/55/image_04757.jpg
#   inflating: /content/Dataset/55/image_04758.jpg
#   inflating: /content/Dataset/55/image_04759.jpg
#   inflating: /content/Dataset/55/image_04760.jpg
#   inflating: /content/Dataset/55/image_04761.jpg
#   inflating: /content/Dataset/55/image_04762.jpg
#   inflating: /content/Dataset/55/image_04763.jpg
#   inflating: /content/Dataset/55/image_04764.jpg
#   inflating: /content/Dataset/55/image_04765.jpg
#   inflating: /content/Dataset/55/image_04766.jpg
#    creating: /content/Dataset/56/
#   inflating: /content/Dataset/56/image_02753.jpg
#   inflating: /content/Dataset/56/image_02754.jpg
#   inflating: /content/Dataset/56/image_02755.jpg
#   inflating: /content/Dataset/56/image_02756.jpg
#   inflating: /content/Dataset/56/image_02757.jpg
#   inflating: /content/Dataset/56/image_02758.jpg
#   inflating: /content/Dataset/56/image_02759.jpg
#   inflating: /content/Dataset/56/image_02760.jpg
#   inflating: /content/Dataset/56/image_02761.jpg
#   inflating: /content/Dataset/56/image_02762.jpg
#   inflating: /content/Dataset/56/image_02763.jpg
#   inflating: /content/Dataset/56/image_02764.jpg
#   inflating: /content/Dataset/56/image_02765.jpg
#   inflating: /content/Dataset/56/image_02766.jpg
#   inflating: /content/Dataset/56/image_02767.jpg
#   inflating: /content/Dataset/56/image_02768.jpg
#   inflating: /content/Dataset/56/image_02769.jpg
#   inflating: /content/Dataset/56/image_02770.jpg
#   inflating: /content/Dataset/56/image_02771.jpg
#   inflating: /content/Dataset/56/image_02772.jpg
#   inflating: /content/Dataset/56/image_02773.jpg
#   inflating: /content/Dataset/56/image_02774.jpg
#   inflating: /content/Dataset/56/image_02775.jpg
#   inflating: /content/Dataset/56/image_02776.jpg
#   inflating: /content/Dataset/56/image_02777.jpg
#   inflating: /content/Dataset/56/image_02778.jpg
#   inflating: /content/Dataset/56/image_02779.jpg
#   inflating: /content/Dataset/56/image_02780.jpg
#   inflating: /content/Dataset/56/image_02781.jpg
#   inflating: /content/Dataset/56/image_02782.jpg
#   inflating: /content/Dataset/56/image_02783.jpg
#   inflating: /content/Dataset/56/image_02784.jpg
#   inflating: /content/Dataset/56/image_02785.jpg
#   inflating: /content/Dataset/56/image_02786.jpg
#   inflating: /content/Dataset/56/image_02787.jpg
#   inflating: /content/Dataset/56/image_02788.jpg
#   inflating: /content/Dataset/56/image_02789.jpg
#   inflating: /content/Dataset/56/image_02790.jpg
#   inflating: /content/Dataset/56/image_02791.jpg
#   inflating: /content/Dataset/56/image_02792.jpg
#   inflating: /content/Dataset/56/image_02793.jpg
#   inflating: /content/Dataset/56/image_02794.jpg
#   inflating: /content/Dataset/56/image_02795.jpg
#   inflating: /content/Dataset/56/image_02796.jpg
#   inflating: /content/Dataset/56/image_02797.jpg
#   inflating: /content/Dataset/56/image_02798.jpg
#   inflating: /content/Dataset/56/image_02799.jpg
#   inflating: /content/Dataset/56/image_02800.jpg
#   inflating: /content/Dataset/56/image_02801.jpg
#   inflating: /content/Dataset/56/image_02802.jpg
#   inflating: /content/Dataset/56/image_02803.jpg
#   inflating: /content/Dataset/56/image_02804.jpg
#   inflating: /content/Dataset/56/image_02805.jpg
#   inflating: /content/Dataset/56/image_02806.jpg
#   inflating: /content/Dataset/56/image_02807.jpg
#   inflating: /content/Dataset/56/image_02808.jpg
#   inflating: /content/Dataset/56/image_02809.jpg
#   inflating: /content/Dataset/56/image_02810.jpg
#   inflating: /content/Dataset/56/image_02811.jpg
#   inflating: /content/Dataset/56/image_02812.jpg
#   inflating: /content/Dataset/56/image_02813.jpg
#   inflating: /content/Dataset/56/image_02814.jpg
#   inflating: /content/Dataset/56/image_02815.jpg
#   inflating: /content/Dataset/56/image_02816.jpg
#   inflating: /content/Dataset/56/image_02817.jpg
#   inflating: /content/Dataset/56/image_02818.jpg
#   inflating: /content/Dataset/56/image_02819.jpg
#   inflating: /content/Dataset/56/image_02820.jpg
#   inflating: /content/Dataset/56/image_02821.jpg
#   inflating: /content/Dataset/56/image_02822.jpg
#   inflating: /content/Dataset/56/image_02823.jpg
#   inflating: /content/Dataset/56/image_02824.jpg
#   inflating: /content/Dataset/56/image_02825.jpg
#   inflating: /content/Dataset/56/image_02826.jpg
#   inflating: /content/Dataset/56/image_02827.jpg
#   inflating: /content/Dataset/56/image_02828.jpg
#   inflating: /content/Dataset/56/image_02829.jpg
#   inflating: /content/Dataset/56/image_02830.jpg
#   inflating: /content/Dataset/56/image_02831.jpg
#   inflating: /content/Dataset/56/image_02832.jpg
#   inflating: /content/Dataset/56/image_02833.jpg
#   inflating: /content/Dataset/56/image_02834.jpg
#   inflating: /content/Dataset/56/image_02835.jpg
#   inflating: /content/Dataset/56/image_02836.jpg
#   inflating: /content/Dataset/56/image_02837.jpg
#   inflating: /content/Dataset/56/image_02838.jpg
#   inflating: /content/Dataset/56/image_02839.jpg
#   inflating: /content/Dataset/56/image_02840.jpg
#   inflating: /content/Dataset/56/image_02841.jpg
#   inflating: /content/Dataset/56/image_02842.jpg
#   inflating: /content/Dataset/56/image_02843.jpg
#   inflating: /content/Dataset/56/image_02844.jpg
#   inflating: /content/Dataset/56/image_02845.jpg
#   inflating: /content/Dataset/56/image_02846.jpg
#   inflating: /content/Dataset/56/image_02847.jpg
#   inflating: /content/Dataset/56/image_02848.jpg
#   inflating: /content/Dataset/56/image_02849.jpg
#   inflating: /content/Dataset/56/image_02850.jpg
#   inflating: /content/Dataset/56/image_02851.jpg
#   inflating: /content/Dataset/56/image_02852.jpg
#   inflating: /content/Dataset/56/image_02853.jpg
#   inflating: /content/Dataset/56/image_02854.jpg
#   inflating: /content/Dataset/56/image_02855.jpg
#   inflating: /content/Dataset/56/image_02856.jpg
#   inflating: /content/Dataset/56/image_02857.jpg
#   inflating: /content/Dataset/56/image_02858.jpg
#   inflating: /content/Dataset/56/image_02859.jpg
#   inflating: /content/Dataset/56/image_02860.jpg
#   inflating: /content/Dataset/56/image_02861.jpg
#    creating: /content/Dataset/57/
#   inflating: /content/Dataset/57/image_07234.jpg
#   inflating: /content/Dataset/57/image_07235.jpg
#   inflating: /content/Dataset/57/image_07236.jpg
#   inflating: /content/Dataset/57/image_07237.jpg
#   inflating: /content/Dataset/57/image_07238.jpg
#   inflating: /content/Dataset/57/image_07239.jpg
#   inflating: /content/Dataset/57/image_07240.jpg
#   inflating: /content/Dataset/57/image_07241.jpg
#   inflating: /content/Dataset/57/image_07242.jpg
#   inflating: /content/Dataset/57/image_07243.jpg
#   inflating: /content/Dataset/57/image_07244.jpg
#   inflating: /content/Dataset/57/image_07245.jpg
#   inflating: /content/Dataset/57/image_07246.jpg
#   inflating: /content/Dataset/57/image_07247.jpg
#   inflating: /content/Dataset/57/image_07248.jpg
#   inflating: /content/Dataset/57/image_07249.jpg
#   inflating: /content/Dataset/57/image_07250.jpg
#   inflating: /content/Dataset/57/image_07251.jpg
#   inflating: /content/Dataset/57/image_07252.jpg
#   inflating: /content/Dataset/57/image_07253.jpg
#   inflating: /content/Dataset/57/image_07254.jpg
#   inflating: /content/Dataset/57/image_07255.jpg
#   inflating: /content/Dataset/57/image_07256.jpg
#   inflating: /content/Dataset/57/image_07257.jpg
#   inflating: /content/Dataset/57/image_07258.jpg
#   inflating: /content/Dataset/57/image_07259.jpg
#   inflating: /content/Dataset/57/image_07260.jpg
#   inflating: /content/Dataset/57/image_07261.jpg
#   inflating: /content/Dataset/57/image_07262.jpg
#   inflating: /content/Dataset/57/image_07263.jpg
#   inflating: /content/Dataset/57/image_07264.jpg
#   inflating: /content/Dataset/57/image_07265.jpg
#   inflating: /content/Dataset/57/image_07266.jpg
#   inflating: /content/Dataset/57/image_07267.jpg
#   inflating: /content/Dataset/57/image_08118.jpg
#   inflating: /content/Dataset/57/image_08119.jpg
#   inflating: /content/Dataset/57/image_08120.jpg
#   inflating: /content/Dataset/57/image_08121.jpg
#   inflating: /content/Dataset/57/image_08122.jpg
#   inflating: /content/Dataset/57/image_08123.jpg
#   inflating: /content/Dataset/57/image_08124.jpg
#   inflating: /content/Dataset/57/image_08125.jpg
#   inflating: /content/Dataset/57/image_08126.jpg
#   inflating: /content/Dataset/57/image_08127.jpg
#   inflating: /content/Dataset/57/image_08128.jpg
#   inflating: /content/Dataset/57/image_08129.jpg
#   inflating: /content/Dataset/57/image_08130.jpg
#   inflating: /content/Dataset/57/image_08131.jpg
#   inflating: /content/Dataset/57/image_08132.jpg
#   inflating: /content/Dataset/57/image_08133.jpg
#   inflating: /content/Dataset/57/image_08134.jpg
#   inflating: /content/Dataset/57/image_08135.jpg
#   inflating: /content/Dataset/57/image_08136.jpg
#   inflating: /content/Dataset/57/image_08137.jpg
#   inflating: /content/Dataset/57/image_08138.jpg
#   inflating: /content/Dataset/57/image_08139.jpg
#   inflating: /content/Dataset/57/image_08140.jpg
#   inflating: /content/Dataset/57/image_08141.jpg
#   inflating: /content/Dataset/57/image_08142.jpg
#   inflating: /content/Dataset/57/image_08143.jpg
#   inflating: /content/Dataset/57/image_08144.jpg
#   inflating: /content/Dataset/57/image_08145.jpg
#   inflating: /content/Dataset/57/image_08146.jpg
#   inflating: /content/Dataset/57/image_08147.jpg
#   inflating: /content/Dataset/57/image_08148.jpg
#   inflating: /content/Dataset/57/image_08149.jpg
#   inflating: /content/Dataset/57/image_08150.jpg
#    creating: /content/Dataset/58/
#   inflating: /content/Dataset/58/image_02639.jpg
#   inflating: /content/Dataset/58/image_02640.jpg
#   inflating: /content/Dataset/58/image_02641.jpg
#   inflating: /content/Dataset/58/image_02642.jpg
#   inflating: /content/Dataset/58/image_02643.jpg
#   inflating: /content/Dataset/58/image_02644.jpg
#   inflating: /content/Dataset/58/image_02645.jpg
#   inflating: /content/Dataset/58/image_02646.jpg
#   inflating: /content/Dataset/58/image_02647.jpg
#   inflating: /content/Dataset/58/image_02648.jpg
#   inflating: /content/Dataset/58/image_02649.jpg
#   inflating: /content/Dataset/58/image_02650.jpg
#   inflating: /content/Dataset/58/image_02651.jpg
#   inflating: /content/Dataset/58/image_02652.jpg
#   inflating: /content/Dataset/58/image_02653.jpg
#   inflating: /content/Dataset/58/image_02654.jpg
#   inflating: /content/Dataset/58/image_02655.jpg
#   inflating: /content/Dataset/58/image_02656.jpg
#   inflating: /content/Dataset/58/image_02657.jpg
#   inflating: /content/Dataset/58/image_02658.jpg
#   inflating: /content/Dataset/58/image_02659.jpg
#   inflating: /content/Dataset/58/image_02660.jpg
#   inflating: /content/Dataset/58/image_02661.jpg
#   inflating: /content/Dataset/58/image_02662.jpg
#   inflating: /content/Dataset/58/image_02663.jpg
#   inflating: /content/Dataset/58/image_02664.jpg
#   inflating: /content/Dataset/58/image_02665.jpg
#   inflating: /content/Dataset/58/image_02666.jpg
#   inflating: /content/Dataset/58/image_02667.jpg
#   inflating: /content/Dataset/58/image_02668.jpg
#   inflating: /content/Dataset/58/image_02669.jpg
#   inflating: /content/Dataset/58/image_02670.jpg
#   inflating: /content/Dataset/58/image_02671.jpg
#   inflating: /content/Dataset/58/image_02672.jpg
#   inflating: /content/Dataset/58/image_02673.jpg
#   inflating: /content/Dataset/58/image_02674.jpg
#   inflating: /content/Dataset/58/image_02675.jpg
#   inflating: /content/Dataset/58/image_02676.jpg
#   inflating: /content/Dataset/58/image_02677.jpg
#   inflating: /content/Dataset/58/image_02678.jpg
#   inflating: /content/Dataset/58/image_02679.jpg
#   inflating: /content/Dataset/58/image_02680.jpg
#   inflating: /content/Dataset/58/image_02681.jpg
#   inflating: /content/Dataset/58/image_02682.jpg
#   inflating: /content/Dataset/58/image_02683.jpg
#   inflating: /content/Dataset/58/image_02684.jpg
#   inflating: /content/Dataset/58/image_02685.jpg
#   inflating: /content/Dataset/58/image_02686.jpg
#   inflating: /content/Dataset/58/image_02687.jpg
#   inflating: /content/Dataset/58/image_02688.jpg
#   inflating: /content/Dataset/58/image_02689.jpg
#   inflating: /content/Dataset/58/image_02690.jpg
#   inflating: /content/Dataset/58/image_02691.jpg
#   inflating: /content/Dataset/58/image_02692.jpg
#   inflating: /content/Dataset/58/image_02693.jpg
#   inflating: /content/Dataset/58/image_02694.jpg
#   inflating: /content/Dataset/58/image_02695.jpg
#   inflating: /content/Dataset/58/image_02696.jpg
#   inflating: /content/Dataset/58/image_02697.jpg
#   inflating: /content/Dataset/58/image_02698.jpg
#   inflating: /content/Dataset/58/image_02699.jpg
#   inflating: /content/Dataset/58/image_02700.jpg
#   inflating: /content/Dataset/58/image_02701.jpg
#   inflating: /content/Dataset/58/image_02702.jpg
#   inflating: /content/Dataset/58/image_02703.jpg
#   inflating: /content/Dataset/58/image_02704.jpg
#   inflating: /content/Dataset/58/image_02705.jpg
#   inflating: /content/Dataset/58/image_02706.jpg
#   inflating: /content/Dataset/58/image_02707.jpg
#   inflating: /content/Dataset/58/image_02708.jpg
#   inflating: /content/Dataset/58/image_02709.jpg
#   inflating: /content/Dataset/58/image_02710.jpg
#   inflating: /content/Dataset/58/image_02711.jpg
#   inflating: /content/Dataset/58/image_02712.jpg
#   inflating: /content/Dataset/58/image_02713.jpg
#   inflating: /content/Dataset/58/image_02714.jpg
#   inflating: /content/Dataset/58/image_02715.jpg
#   inflating: /content/Dataset/58/image_02716.jpg
#   inflating: /content/Dataset/58/image_02717.jpg
#   inflating: /content/Dataset/58/image_02718.jpg
#   inflating: /content/Dataset/58/image_02719.jpg
#   inflating: /content/Dataset/58/image_02720.jpg
#   inflating: /content/Dataset/58/image_02721.jpg
#   inflating: /content/Dataset/58/image_02722.jpg
#   inflating: /content/Dataset/58/image_02723.jpg
#   inflating: /content/Dataset/58/image_02724.jpg
#   inflating: /content/Dataset/58/image_02725.jpg
#   inflating: /content/Dataset/58/image_02726.jpg
#   inflating: /content/Dataset/58/image_02727.jpg
#   inflating: /content/Dataset/58/image_02728.jpg
#   inflating: /content/Dataset/58/image_02729.jpg
#   inflating: /content/Dataset/58/image_02730.jpg
#   inflating: /content/Dataset/58/image_02731.jpg
#   inflating: /content/Dataset/58/image_02732.jpg
#   inflating: /content/Dataset/58/image_02733.jpg
#   inflating: /content/Dataset/58/image_02734.jpg
#   inflating: /content/Dataset/58/image_02735.jpg
#   inflating: /content/Dataset/58/image_02736.jpg
#   inflating: /content/Dataset/58/image_02737.jpg
#   inflating: /content/Dataset/58/image_02738.jpg
#   inflating: /content/Dataset/58/image_02739.jpg
#   inflating: /content/Dataset/58/image_02740.jpg
#   inflating: /content/Dataset/58/image_02741.jpg
#   inflating: /content/Dataset/58/image_02742.jpg
#   inflating: /content/Dataset/58/image_02743.jpg
#   inflating: /content/Dataset/58/image_02744.jpg
#   inflating: /content/Dataset/58/image_02745.jpg
#   inflating: /content/Dataset/58/image_02746.jpg
#   inflating: /content/Dataset/58/image_02747.jpg
#   inflating: /content/Dataset/58/image_02748.jpg
#   inflating: /content/Dataset/58/image_02749.jpg
#   inflating: /content/Dataset/58/image_02750.jpg
#   inflating: /content/Dataset/58/image_02751.jpg
#   inflating: /content/Dataset/58/image_02752.jpg
#    creating: /content/Dataset/59/
#   inflating: /content/Dataset/59/image_05020.jpg
#   inflating: /content/Dataset/59/image_05021.jpg
#   inflating: /content/Dataset/59/image_05022.jpg
#   inflating: /content/Dataset/59/image_05023.jpg
#   inflating: /content/Dataset/59/image_05024.jpg
#   inflating: /content/Dataset/59/image_05025.jpg
#   inflating: /content/Dataset/59/image_05026.jpg
#   inflating: /content/Dataset/59/image_05027.jpg
#   inflating: /content/Dataset/59/image_05028.jpg
#   inflating: /content/Dataset/59/image_05029.jpg
#   inflating: /content/Dataset/59/image_05030.jpg
#   inflating: /content/Dataset/59/image_05031.jpg
#   inflating: /content/Dataset/59/image_05032.jpg
#   inflating: /content/Dataset/59/image_05033.jpg
#   inflating: /content/Dataset/59/image_05034.jpg
#   inflating: /content/Dataset/59/image_05035.jpg
#   inflating: /content/Dataset/59/image_05036.jpg
#   inflating: /content/Dataset/59/image_05037.jpg
#   inflating: /content/Dataset/59/image_05038.jpg
#   inflating: /content/Dataset/59/image_05039.jpg
#   inflating: /content/Dataset/59/image_05040.jpg
#   inflating: /content/Dataset/59/image_05041.jpg
#   inflating: /content/Dataset/59/image_05042.jpg
#   inflating: /content/Dataset/59/image_05043.jpg
#   inflating: /content/Dataset/59/image_05044.jpg
#   inflating: /content/Dataset/59/image_05045.jpg
#   inflating: /content/Dataset/59/image_05046.jpg
#   inflating: /content/Dataset/59/image_05047.jpg
#   inflating: /content/Dataset/59/image_05048.jpg
#   inflating: /content/Dataset/59/image_05049.jpg
#   inflating: /content/Dataset/59/image_05050.jpg
#   inflating: /content/Dataset/59/image_05051.jpg
#   inflating: /content/Dataset/59/image_05052.jpg
#   inflating: /content/Dataset/59/image_05053.jpg
#   inflating: /content/Dataset/59/image_05054.jpg
#   inflating: /content/Dataset/59/image_05055.jpg
#   inflating: /content/Dataset/59/image_05056.jpg
#   inflating: /content/Dataset/59/image_05057.jpg
#   inflating: /content/Dataset/59/image_05058.jpg
#   inflating: /content/Dataset/59/image_05059.jpg
#   inflating: /content/Dataset/59/image_05060.jpg
#   inflating: /content/Dataset/59/image_05061.jpg
#   inflating: /content/Dataset/59/image_05062.jpg
#   inflating: /content/Dataset/59/image_05063.jpg
#   inflating: /content/Dataset/59/image_05064.jpg
#   inflating: /content/Dataset/59/image_05065.jpg
#   inflating: /content/Dataset/59/image_05066.jpg
#   inflating: /content/Dataset/59/image_05067.jpg
#   inflating: /content/Dataset/59/image_05068.jpg
#   inflating: /content/Dataset/59/image_05069.jpg
#   inflating: /content/Dataset/59/image_05070.jpg
#   inflating: /content/Dataset/59/image_05071.jpg
#   inflating: /content/Dataset/59/image_05072.jpg
#   inflating: /content/Dataset/59/image_05073.jpg
#   inflating: /content/Dataset/59/image_05074.jpg
#   inflating: /content/Dataset/59/image_05075.jpg
#   inflating: /content/Dataset/59/image_05076.jpg
#   inflating: /content/Dataset/59/image_05077.jpg
#   inflating: /content/Dataset/59/image_05078.jpg
#   inflating: /content/Dataset/59/image_05079.jpg
#   inflating: /content/Dataset/59/image_05080.jpg
#   inflating: /content/Dataset/59/image_05081.jpg
#   inflating: /content/Dataset/59/image_05082.jpg
#   inflating: /content/Dataset/59/image_05083.jpg
#   inflating: /content/Dataset/59/image_05084.jpg
#   inflating: /content/Dataset/59/image_05085.jpg
#   inflating: /content/Dataset/59/image_05086.jpg
#    creating: /content/Dataset/6/
#   inflating: /content/Dataset/6/image_07162.jpg
#   inflating: /content/Dataset/6/image_07163.jpg
#   inflating: /content/Dataset/6/image_07164.jpg
#   inflating: /content/Dataset/6/image_07165.jpg
#   inflating: /content/Dataset/6/image_07166.jpg
#   inflating: /content/Dataset/6/image_07167.jpg
#   inflating: /content/Dataset/6/image_07168.jpg
#   inflating: /content/Dataset/6/image_07169.jpg
#   inflating: /content/Dataset/6/image_07170.jpg
#   inflating: /content/Dataset/6/image_07171.jpg
#   inflating: /content/Dataset/6/image_07172.jpg
#   inflating: /content/Dataset/6/image_07173.jpg
#   inflating: /content/Dataset/6/image_07174.jpg
#   inflating: /content/Dataset/6/image_07175.jpg
#   inflating: /content/Dataset/6/image_07176.jpg
#   inflating: /content/Dataset/6/image_07177.jpg
#   inflating: /content/Dataset/6/image_07178.jpg
#   inflating: /content/Dataset/6/image_07179.jpg
#   inflating: /content/Dataset/6/image_07180.jpg
#   inflating: /content/Dataset/6/image_07181.jpg
#   inflating: /content/Dataset/6/image_07182.jpg
#   inflating: /content/Dataset/6/image_07183.jpg
#   inflating: /content/Dataset/6/image_07184.jpg
#   inflating: /content/Dataset/6/image_07185.jpg
#   inflating: /content/Dataset/6/image_07186.jpg
#   inflating: /content/Dataset/6/image_07187.jpg
#   inflating: /content/Dataset/6/image_07188.jpg
#   inflating: /content/Dataset/6/image_07189.jpg
#   inflating: /content/Dataset/6/image_07190.jpg
#   inflating: /content/Dataset/6/image_07191.jpg
#   inflating: /content/Dataset/6/image_07192.jpg
#   inflating: /content/Dataset/6/image_07193.jpg
#   inflating: /content/Dataset/6/image_07194.jpg
#   inflating: /content/Dataset/6/image_07195.jpg
#   inflating: /content/Dataset/6/image_07196.jpg
#   inflating: /content/Dataset/6/image_07197.jpg
#   inflating: /content/Dataset/6/image_07198.jpg
#   inflating: /content/Dataset/6/image_07199.jpg
#   inflating: /content/Dataset/6/image_08105.jpg
#   inflating: /content/Dataset/6/image_08106.jpg
#   inflating: /content/Dataset/6/image_08107.jpg
#   inflating: /content/Dataset/6/image_08108.jpg
#   inflating: /content/Dataset/6/image_08109.jpg
#   inflating: /content/Dataset/6/image_08110.jpg
#   inflating: /content/Dataset/6/image_08111.jpg
#    creating: /content/Dataset/60/
#   inflating: /content/Dataset/60/image_02920.jpg
#   inflating: /content/Dataset/60/image_02921.jpg
#   inflating: /content/Dataset/60/image_02922.jpg
#   inflating: /content/Dataset/60/image_02923.jpg
#   inflating: /content/Dataset/60/image_02924.jpg
#   inflating: /content/Dataset/60/image_02925.jpg
#   inflating: /content/Dataset/60/image_02926.jpg
#   inflating: /content/Dataset/60/image_02927.jpg
#   inflating: /content/Dataset/60/image_02928.jpg
#   inflating: /content/Dataset/60/image_02929.jpg
#   inflating: /content/Dataset/60/image_02930.jpg
#   inflating: /content/Dataset/60/image_02931.jpg
#   inflating: /content/Dataset/60/image_02932.jpg
#   inflating: /content/Dataset/60/image_02933.jpg
#   inflating: /content/Dataset/60/image_02934.jpg
#   inflating: /content/Dataset/60/image_02935.jpg
#   inflating: /content/Dataset/60/image_02936.jpg
#   inflating: /content/Dataset/60/image_02937.jpg
#   inflating: /content/Dataset/60/image_02938.jpg
#   inflating: /content/Dataset/60/image_02939.jpg
#   inflating: /content/Dataset/60/image_02940.jpg
#   inflating: /content/Dataset/60/image_02941.jpg
#   inflating: /content/Dataset/60/image_02942.jpg
#   inflating: /content/Dataset/60/image_02943.jpg
#   inflating: /content/Dataset/60/image_02944.jpg
#   inflating: /content/Dataset/60/image_02945.jpg
#   inflating: /content/Dataset/60/image_02946.jpg
#   inflating: /content/Dataset/60/image_02947.jpg
#   inflating: /content/Dataset/60/image_02948.jpg
#   inflating: /content/Dataset/60/image_02949.jpg
#   inflating: /content/Dataset/60/image_02950.jpg
# ...
#   inflating: /content/Dataset/95/image_07585.jpg
#   inflating: /content/Dataset/95/image_07586.jpg
#   inflating: /content/Dataset/95/image_07587.jpg
#   inflating: /content/Dataset/95/image_07588.jpg
#   inflating: /content/Dataset/95/image_07589.jpg
#   inflating: /content/Dataset/95/image_07590.jpg
#   inflating: /content/Dataset/95/image_07591.jpg
#   inflating: /content/Dataset/95/image_07592.jpg
#   inflating: /content/Dataset/95/image_07593.jpg
#    creating: /content/Dataset/96/
#   inflating: /content/Dataset/96/image_07594.jpg
#   inflating: /content/Dataset/96/image_07595.jpg
#   inflating: /content/Dataset/96/image_07596.jpg
#   inflating: /content/Dataset/96/image_07597.jpg
#   inflating: /content/Dataset/96/image_07598.jpg
#   inflating: /content/Dataset/96/image_07599.jpg
#   inflating: /content/Dataset/96/image_07600.jpg
#   inflating: /content/Dataset/96/image_07601.jpg
#   inflating: /content/Dataset/96/image_07602.jpg
#   inflating: /content/Dataset/96/image_07603.jpg
#   inflating: /content/Dataset/96/image_07604.jpg
#   inflating: /content/Dataset/96/image_07605.jpg
#   inflating: /content/Dataset/96/image_07606.jpg
#   inflating: /content/Dataset/96/image_07607.jpg
#   inflating: /content/Dataset/96/image_07608.jpg
#   inflating: /content/Dataset/96/image_07609.jpg
#   inflating: /content/Dataset/96/image_07610.jpg
#   inflating: /content/Dataset/96/image_07611.jpg
#   inflating: /content/Dataset/96/image_07612.jpg
#   inflating: /content/Dataset/96/image_07613.jpg
#   inflating: /content/Dataset/96/image_07614.jpg
#   inflating: /content/Dataset/96/image_07615.jpg
#   inflating: /content/Dataset/96/image_07616.jpg
#   inflating: /content/Dataset/96/image_07617.jpg
#   inflating: /content/Dataset/96/image_07618.jpg
#   inflating: /content/Dataset/96/image_07619.jpg
#   inflating: /content/Dataset/96/image_07620.jpg
#   inflating: /content/Dataset/96/image_07621.jpg
#   inflating: /content/Dataset/96/image_07622.jpg
#   inflating: /content/Dataset/96/image_07623.jpg
#   inflating: /content/Dataset/96/image_07624.jpg
#   inflating: /content/Dataset/96/image_07625.jpg
#   inflating: /content/Dataset/96/image_07626.jpg
#   inflating: /content/Dataset/96/image_07627.jpg
#   inflating: /content/Dataset/96/image_07628.jpg
#   inflating: /content/Dataset/96/image_07629.jpg
#   inflating: /content/Dataset/96/image_07630.jpg
#   inflating: /content/Dataset/96/image_07631.jpg
#   inflating: /content/Dataset/96/image_07632.jpg
#   inflating: /content/Dataset/96/image_07633.jpg
#   inflating: /content/Dataset/96/image_07634.jpg
#   inflating: /content/Dataset/96/image_07635.jpg
#   inflating: /content/Dataset/96/image_07636.jpg
#   inflating: /content/Dataset/96/image_07637.jpg
#   inflating: /content/Dataset/96/image_07638.jpg
#   inflating: /content/Dataset/96/image_07639.jpg
#   inflating: /content/Dataset/96/image_07640.jpg
#   inflating: /content/Dataset/96/image_07641.jpg
#   inflating: /content/Dataset/96/image_07642.jpg
#   inflating: /content/Dataset/96/image_07643.jpg
#   inflating: /content/Dataset/96/image_07644.jpg
#   inflating: /content/Dataset/96/image_07645.jpg
#   inflating: /content/Dataset/96/image_07646.jpg
#   inflating: /content/Dataset/96/image_07647.jpg
#   inflating: /content/Dataset/96/image_07648.jpg
#   inflating: /content/Dataset/96/image_07649.jpg
#   inflating: /content/Dataset/96/image_07650.jpg
#   inflating: /content/Dataset/96/image_07651.jpg
#   inflating: /content/Dataset/96/image_07652.jpg
#   inflating: /content/Dataset/96/image_07653.jpg
#   inflating: /content/Dataset/96/image_07654.jpg
#   inflating: /content/Dataset/96/image_07655.jpg
#   inflating: /content/Dataset/96/image_07656.jpg
#   inflating: /content/Dataset/96/image_07657.jpg
#   inflating: /content/Dataset/96/image_07658.jpg
#   inflating: /content/Dataset/96/image_07659.jpg
#   inflating: /content/Dataset/96/image_07660.jpg
#   inflating: /content/Dataset/96/image_07661.jpg
#   inflating: /content/Dataset/96/image_07662.jpg
#   inflating: /content/Dataset/96/image_07663.jpg
#   inflating: /content/Dataset/96/image_07664.jpg
#   inflating: /content/Dataset/96/image_07665.jpg
#   inflating: /content/Dataset/96/image_07666.jpg
#   inflating: /content/Dataset/96/image_07667.jpg
#   inflating: /content/Dataset/96/image_07668.jpg
#   inflating: /content/Dataset/96/image_07669.jpg
#   inflating: /content/Dataset/96/image_07670.jpg
#   inflating: /content/Dataset/96/image_07671.jpg
#   inflating: /content/Dataset/96/image_07672.jpg
#   inflating: /content/Dataset/96/image_07673.jpg
#   inflating: /content/Dataset/96/image_07674.jpg
#   inflating: /content/Dataset/96/image_07675.jpg
#   inflating: /content/Dataset/96/image_07676.jpg
#   inflating: /content/Dataset/96/image_07677.jpg
#   inflating: /content/Dataset/96/image_07678.jpg
#   inflating: /content/Dataset/96/image_07679.jpg
#   inflating: /content/Dataset/96/image_07680.jpg
#   inflating: /content/Dataset/96/image_07681.jpg
#   inflating: /content/Dataset/96/image_07682.jpg
#   inflating: /content/Dataset/96/image_07683.jpg
#   inflating: /content/Dataset/96/image_07684.jpg
#    creating: /content/Dataset/97/
#   inflating: /content/Dataset/97/image_07685.jpg
#   inflating: /content/Dataset/97/image_07686.jpg
#   inflating: /content/Dataset/97/image_07687.jpg
#   inflating: /content/Dataset/97/image_07688.jpg
#   inflating: /content/Dataset/97/image_07689.jpg
#   inflating: /content/Dataset/97/image_07690.jpg
#   inflating: /content/Dataset/97/image_07691.jpg
#   inflating: /content/Dataset/97/image_07692.jpg
#   inflating: /content/Dataset/97/image_07693.jpg
#   inflating: /content/Dataset/97/image_07694.jpg
#   inflating: /content/Dataset/97/image_07695.jpg
#   inflating: /content/Dataset/97/image_07696.jpg
#   inflating: /content/Dataset/97/image_07697.jpg
#   inflating: /content/Dataset/97/image_07698.jpg
#   inflating: /content/Dataset/97/image_07699.jpg
#   inflating: /content/Dataset/97/image_07700.jpg
#   inflating: /content/Dataset/97/image_07701.jpg
#   inflating: /content/Dataset/97/image_07702.jpg
#   inflating: /content/Dataset/97/image_07703.jpg
#   inflating: /content/Dataset/97/image_07704.jpg
#   inflating: /content/Dataset/97/image_07705.jpg
#   inflating: /content/Dataset/97/image_07706.jpg
#   inflating: /content/Dataset/97/image_07707.jpg
#   inflating: /content/Dataset/97/image_07708.jpg
#   inflating: /content/Dataset/97/image_07709.jpg
#   inflating: /content/Dataset/97/image_07710.jpg
#   inflating: /content/Dataset/97/image_07711.jpg
#   inflating: /content/Dataset/97/image_07712.jpg
#   inflating: /content/Dataset/97/image_07713.jpg
#   inflating: /content/Dataset/97/image_07714.jpg
#   inflating: /content/Dataset/97/image_07715.jpg
#   inflating: /content/Dataset/97/image_07716.jpg
#   inflating: /content/Dataset/97/image_07717.jpg
#   inflating: /content/Dataset/97/image_07718.jpg
#   inflating: /content/Dataset/97/image_07719.jpg
#   inflating: /content/Dataset/97/image_07720.jpg
#   inflating: /content/Dataset/97/image_07721.jpg
#   inflating: /content/Dataset/97/image_07722.jpg
#   inflating: /content/Dataset/97/image_07723.jpg
#   inflating: /content/Dataset/97/image_07724.jpg
#   inflating: /content/Dataset/97/image_07725.jpg
#   inflating: /content/Dataset/97/image_07726.jpg
#   inflating: /content/Dataset/97/image_07727.jpg
#   inflating: /content/Dataset/97/image_07728.jpg
#   inflating: /content/Dataset/97/image_07729.jpg
#   inflating: /content/Dataset/97/image_07730.jpg
#   inflating: /content/Dataset/97/image_07731.jpg
#   inflating: /content/Dataset/97/image_07732.jpg
#   inflating: /content/Dataset/97/image_07733.jpg
#   inflating: /content/Dataset/97/image_07734.jpg
#   inflating: /content/Dataset/97/image_07735.jpg
#   inflating: /content/Dataset/97/image_07736.jpg
#   inflating: /content/Dataset/97/image_07737.jpg
#   inflating: /content/Dataset/97/image_07738.jpg
#   inflating: /content/Dataset/97/image_07739.jpg
#   inflating: /content/Dataset/97/image_07740.jpg
#   inflating: /content/Dataset/97/image_07741.jpg
#   inflating: /content/Dataset/97/image_07742.jpg
#   inflating: /content/Dataset/97/image_07743.jpg
#   inflating: /content/Dataset/97/image_07744.jpg
#   inflating: /content/Dataset/97/image_07745.jpg
#   inflating: /content/Dataset/97/image_07746.jpg
#   inflating: /content/Dataset/97/image_07747.jpg
#   inflating: /content/Dataset/97/image_07748.jpg
#   inflating: /content/Dataset/97/image_07749.jpg
#   inflating: /content/Dataset/97/image_07750.jpg
#    creating: /content/Dataset/98/
#   inflating: /content/Dataset/98/image_07751.jpg
#   inflating: /content/Dataset/98/image_07752.jpg
#   inflating: /content/Dataset/98/image_07753.jpg
#   inflating: /content/Dataset/98/image_07754.jpg
#   inflating: /content/Dataset/98/image_07755.jpg
#   inflating: /content/Dataset/98/image_07756.jpg
#   inflating: /content/Dataset/98/image_07757.jpg
#   inflating: /content/Dataset/98/image_07758.jpg
#   inflating: /content/Dataset/98/image_07759.jpg
#   inflating: /content/Dataset/98/image_07760.jpg
#   inflating: /content/Dataset/98/image_07761.jpg
#   inflating: /content/Dataset/98/image_07762.jpg
#   inflating: /content/Dataset/98/image_07763.jpg
#   inflating: /content/Dataset/98/image_07764.jpg
#   inflating: /content/Dataset/98/image_07765.jpg
#   inflating: /content/Dataset/98/image_07766.jpg
#   inflating: /content/Dataset/98/image_07767.jpg
#   inflating: /content/Dataset/98/image_07768.jpg
#   inflating: /content/Dataset/98/image_07769.jpg
#   inflating: /content/Dataset/98/image_07770.jpg
#   inflating: /content/Dataset/98/image_07771.jpg
#   inflating: /content/Dataset/98/image_07772.jpg
#   inflating: /content/Dataset/98/image_07773.jpg
#   inflating: /content/Dataset/98/image_07774.jpg
#   inflating: /content/Dataset/98/image_07775.jpg
#   inflating: /content/Dataset/98/image_07776.jpg
#   inflating: /content/Dataset/98/image_07777.jpg
#   inflating: /content/Dataset/98/image_07778.jpg
#   inflating: /content/Dataset/98/image_07779.jpg
#   inflating: /content/Dataset/98/image_07780.jpg
#   inflating: /content/Dataset/98/image_07781.jpg
#   inflating: /content/Dataset/98/image_07782.jpg
#   inflating: /content/Dataset/98/image_07783.jpg
#   inflating: /content/Dataset/98/image_07784.jpg
#   inflating: /content/Dataset/98/image_07785.jpg
#   inflating: /content/Dataset/98/image_07786.jpg
#   inflating: /content/Dataset/98/image_07787.jpg
#   inflating: /content/Dataset/98/image_07788.jpg
#   inflating: /content/Dataset/98/image_07789.jpg
#   inflating: /content/Dataset/98/image_07790.jpg
#   inflating: /content/Dataset/98/image_07791.jpg
#   inflating: /content/Dataset/98/image_07792.jpg
#   inflating: /content/Dataset/98/image_07793.jpg
#   inflating: /content/Dataset/98/image_07794.jpg
#   inflating: /content/Dataset/98/image_07795.jpg
#   inflating: /content/Dataset/98/image_07796.jpg
#   inflating: /content/Dataset/98/image_07797.jpg
#   inflating: /content/Dataset/98/image_07798.jpg
#   inflating: /content/Dataset/98/image_07799.jpg
#   inflating: /content/Dataset/98/image_07800.jpg
#   inflating: /content/Dataset/98/image_07801.jpg
#   inflating: /content/Dataset/98/image_07802.jpg
#   inflating: /content/Dataset/98/image_07803.jpg
#   inflating: /content/Dataset/98/image_07804.jpg
#   inflating: /content/Dataset/98/image_07805.jpg
#   inflating: /content/Dataset/98/image_07806.jpg
#   inflating: /content/Dataset/98/image_07807.jpg
#   inflating: /content/Dataset/98/image_07808.jpg
#   inflating: /content/Dataset/98/image_07809.jpg
#   inflating: /content/Dataset/98/image_07810.jpg
#   inflating: /content/Dataset/98/image_07811.jpg
#   inflating: /content/Dataset/98/image_07812.jpg
#   inflating: /content/Dataset/98/image_07813.jpg
#   inflating: /content/Dataset/98/image_07814.jpg
#   inflating: /content/Dataset/98/image_07815.jpg
#   inflating: /content/Dataset/98/image_07816.jpg
#   inflating: /content/Dataset/98/image_07817.jpg
#   inflating: /content/Dataset/98/image_07818.jpg
#   inflating: /content/Dataset/98/image_07819.jpg
#   inflating: /content/Dataset/98/image_07820.jpg
#   inflating: /content/Dataset/98/image_07821.jpg
#   inflating: /content/Dataset/98/image_07822.jpg
#   inflating: /content/Dataset/98/image_07823.jpg
#   inflating: /content/Dataset/98/image_07824.jpg
#   inflating: /content/Dataset/98/image_07825.jpg
#   inflating: /content/Dataset/98/image_07826.jpg
#   inflating: /content/Dataset/98/image_07827.jpg
#   inflating: /content/Dataset/98/image_07828.jpg
#   inflating: /content/Dataset/98/image_07829.jpg
#   inflating: /content/Dataset/98/image_07830.jpg
#   inflating: /content/Dataset/98/image_07831.jpg
#   inflating: /content/Dataset/98/image_07832.jpg
#    creating: /content/Dataset/99/
#   inflating: /content/Dataset/99/image_07833.jpg
#   inflating: /content/Dataset/99/image_07834.jpg
#   inflating: /content/Dataset/99/image_07835.jpg
#   inflating: /content/Dataset/99/image_07836.jpg
#   inflating: /content/Dataset/99/image_07837.jpg
#   inflating: /content/Dataset/99/image_07838.jpg
#   inflating: /content/Dataset/99/image_07839.jpg
#   inflating: /content/Dataset/99/image_07840.jpg
#   inflating: /content/Dataset/99/image_07841.jpg
#   inflating: /content/Dataset/99/image_07842.jpg
#   inflating: /content/Dataset/99/image_07843.jpg
#   inflating: /content/Dataset/99/image_07844.jpg
#   inflating: /content/Dataset/99/image_07845.jpg
#   inflating: /content/Dataset/99/image_07846.jpg
#   inflating: /content/Dataset/99/image_07847.jpg
#   inflating: /content/Dataset/99/image_07848.jpg
#   inflating: /content/Dataset/99/image_07849.jpg
#   inflating: /content/Dataset/99/image_07850.jpg
#   inflating: /content/Dataset/99/image_07851.jpg
#   inflating: /content/Dataset/99/image_07852.jpg
#   inflating: /content/Dataset/99/image_07853.jpg
#   inflating: /content/Dataset/99/image_07854.jpg
#   inflating: /content/Dataset/99/image_07855.jpg
#   inflating: /content/Dataset/99/image_07856.jpg
#   inflating: /content/Dataset/99/image_07857.jpg
#   inflating: /content/Dataset/99/image_07858.jpg
#   inflating: /content/Dataset/99/image_07859.jpg
#   inflating: /content/Dataset/99/image_07860.jpg
#   inflating: /content/Dataset/99/image_07861.jpg
#   inflating: /content/Dataset/99/image_07862.jpg
#   inflating: /content/Dataset/99/image_07863.jpg
#   inflating: /content/Dataset/99/image_07864.jpg
#   inflating: /content/Dataset/99/image_07865.jpg
#   inflating: /content/Dataset/99/image_07866.jpg
#   inflating: /content/Dataset/99/image_07867.jpg
#   inflating: /content/Dataset/99/image_07868.jpg
#   inflating: /content/Dataset/99/image_07869.jpg
#   inflating: /content/Dataset/99/image_07870.jpg
#   inflating: /content/Dataset/99/image_07871.jpg
#   inflating: /content/Dataset/99/image_07872.jpg
#   inflating: /content/Dataset/99/image_07873.jpg
#   inflating: /content/Dataset/99/image_07874.jpg
#   inflating: /content/Dataset/99/image_07875.jpg
#   inflating: /content/Dataset/99/image_07876.jpg
#   inflating: /content/Dataset/99/image_07877.jpg
#   inflating: /content/Dataset/99/image_07878.jpg
#   inflating: /content/Dataset/99/image_07879.jpg
#   inflating: /content/Dataset/99/image_07880.jpg
#   inflating: /content/Dataset/99/image_07881.jpg
#   inflating: /content/Dataset/99/image_07882.jpg
#   inflating: /content/Dataset/99/image_07883.jpg
#   inflating: /content/Dataset/99/image_07884.jpg
#   inflating: /content/Dataset/99/image_07885.jpg
#   inflating: /content/Dataset/99/image_07886.jpg
#   inflating: /content/Dataset/99/image_07887.jpg
#   inflating: /content/Dataset/99/image_07888.jpg
#   inflating: /content/Dataset/99/image_07889.jpg
#   inflating: /content/Dataset/99/image_07890.jpg
#   inflating: /content/Dataset/99/image_07891.jpg
#   inflating: /content/Dataset/99/image_07892.jpg
#   inflating: /content/Dataset/99/image_08062.jpg
#   inflating: /content/Dataset/99/image_08063.jpg
#   inflating: /content/Dataset/99/image_08064.jpg

# %%
import os
import glob
import torch
from torch.utils.data import Dataset, DataLoader, Subset, WeightedRandomSampler
from PIL import Image
from torchvision import transforms
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
root_folder = '/content/Dataset'
seed = 1234
torch.manual_seed(seed)

# %% [markdown]
# # Dataset Loader

# %% [markdown]
# ## Dataset Defenition

# %%
class ImageFolderDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.class_folders = [f for f in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, f))]
        self.image_paths = []
        self.labels = []

        for label, class_folder in enumerate(self.class_folders):
            img_paths = glob.glob(os.path.join(root_dir, class_folder, '*.jpg'))
            self.image_paths.extend(img_paths)
            self.labels.extend([label] * len(img_paths))

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
def stratified_split(dataset, test_size=0.1, val_size=0.2, random_state=seed):
    indices = list(range(len(dataset)))
    labels = dataset.labels

    # Split indices for train+val and test sets
    train_val_indices, test_indices = train_test_split(
        indices, test_size=test_size, stratify=labels, random_state=random_state
    )

    # Split indices for train and validation sets
    train_indices, val_indices = train_test_split(
        train_val_indices, test_size=val_size, stratify=[labels[i] for i in train_val_indices], random_state=random_state
    )

    train_dataset = Subset(dataset, train_indices)
    val_dataset = Subset(dataset, val_indices)
    test_dataset = Subset(dataset, test_indices)

    return train_dataset, val_dataset, test_dataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define transformations
transform = transforms.Compose([
    transforms.Resize((400, 400)),
    transforms.ToTensor(),
])

# Load images from the folder using custom dataset
dataset = ImageFolderDataset( root_dir=root_folder,
                             transform=transform)

# %% [markdown]
# ## split data to Train, Validation and Test sets

# %%
train_dataset, val_dataset, test_dataset = stratified_split(dataset)

# %%
# Print the number of samples in each set
print(f'Training set: {len(train_dataset)} samples')
print(f'Validation set: {len(val_dataset)} samples')
print(f'Test set: {len(test_dataset)} samples')
# Out:
# Training set: 5896 samples
# Validation set: 1474 samples
# Test set: 819 samples

# %% [markdown]
# ### Split distribution

# %%
save_plots_path = '/content/training'

if not os.path.exists(save_plots_path):
    os.mkdir(save_plots_path)


def plot_dataset_distribution(dataset,title):
    plt.figure(figsize=(14,7))
    plt.hist(dataset.labels, bins=[x for x in range(1,103)], density=True)
    plt.title(title)
    plt.xlabel('Category')
    plt.ylabel('Category Density')
    path = os.path.join(save_plots_path, f'{title}.jpg')
    plt.savefig(path, bbox_inches='tight', dpi=300)
    plt.show()

# %%
plot_dataset_distribution(dataset,'Dataset')

# %%
plot_dataset_distribution(train_dataset.dataset,'Train Dataset')

# %%
plot_dataset_distribution(val_dataset.dataset,'Validation Dataset')

# %%
plot_dataset_distribution(test_dataset.dataset,'Test Dataset')

# %% [markdown]
# ## Biuld DataLoaders with Upsampling

# %%
labales_list = [dataset.labels[x] for x in train_dataset.indices]
class_counts = np.bincount(labales_list)
class_weights = 1. / class_counts
sample_weights = class_weights[labales_list]
train_sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights)*2, replacement=True)
train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)

# %%
def collect_labels(dataloader):
    all_labels = []
    for _, labels in dataloader:
        all_labels.extend(labels.numpy())
    return np.array(all_labels)

train_labels_upsampled = collect_labels(train_loader)
plt.figure(figsize=(14,7))
plt.hist(train_labels_upsampled, bins=[x for x in range(1,103)], density=True)
plt.title('Upsampled Train distribution')
plt.xlabel('Category')
plt.ylabel('Category Density')
plt.show()

# %%
labales_list = [dataset.labels[x] for x in val_dataset.indices]
class_counts = np.bincount(labales_list)
class_weights = 1. / class_counts
sample_weights = class_weights[labales_list]
val_sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights)*2, replacement=True)
val_loader = DataLoader(val_dataset, batch_size=32, sampler=val_sampler)

# %%
labales_list = [dataset.labels[x] for x in test_dataset.indices]
class_counts = np.bincount(labales_list)
class_weights = 1. / class_counts
sample_weights = class_weights[labales_list]
test_sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights)*2, replacement=True)
test_loader = DataLoader(test_dataset, batch_size=32, sampler=test_sampler)

# %%
# Print the number of samples in each set
print(f'Training set: {len(train_loader.dataset)} samples')
print(f'Validation set: {len(val_loader.dataset)} samples')
print(f'Test set: {len(test_loader.dataset)} samples')
# Out:
# Training set: 5896 samples
# Validation set: 1474 samples
# Test set: 819 samples

# %% [markdown]
# # Model Training

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from torchvision import models

# %%
features_dim = 10 # dimension of representation

# %% [markdown]
# ## define CenterLoss And Model Architecture

# %%
class CenteredLoss(nn.Module):
    def __init__(self, num_classes, feature_dim):
        super(CenteredLoss, self).__init__()
        self.num_classes = num_classes
        self.feature_dim = feature_dim
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        # Initialize the centers for each class
        self.centers = nn.Parameter(torch.randn(num_classes, feature_dim).to(self.device))

        # Initialize containers to store features and labels
        self.features_list = []
        self.labels_list = []

    def forward(self, features, labels):
        # Save features and labels for center updating
        self.features_list.append(features.detach().cpu())
        self.labels_list.append(labels.detach().cpu())

        # Get the centers of the corresponding labels
        centers_batch = self.centers.index_select(0, labels)

        # Calculate the centered loss
        loss = F.mse_loss(features, centers_batch)

        return loss

    def update_centers(self):
        # Concatenate all saved features and labels
        features = torch.cat(self.features_list, dim=0)
        labels = torch.cat(self.labels_list, dim=0)

        # Reset lists for the next epoch
        self.features_list = []
        self.labels_list = []

        # Calculate new centers
        new_centers = torch.zeros_like(self.centers)
        for i in range(self.num_classes):
            mask = (labels == i)
            if mask.sum() > 0:
                new_centers[i] = features[mask].mean(dim=0)

        self.centers.data = new_centers.to(self.device)


class CombinedModel(nn.Module):
    def __init__(self, num_classes, alpha=0.5):
        super(CombinedModel, self).__init__()
        self.alpha = alpha
        self.base_model = models.resnet18(pretrained=True)

        for name, param in self.base_model.named_parameters():
            if 'layer1' in name or 'layer2' in name:
                param.requires_grad = False # freeze deep layers

        self.base_model.fc = nn.Sequential(
            nn.Linear(self.base_model.fc.in_features, features_dim),
        )

        self.classifier = nn.Linear(features_dim, num_classes)
        self.centered_loss_fn = CenteredLoss(num_classes, features_dim)

    def forward(self, x):
        features = self.base_model(x)
        logits = self.classifier(features)
        return features, logits

    def compute_loss(self, features, logits, labels):
        softmax_loss = nn.CrossEntropyLoss()(logits, labels)
        centered_loss = self.centered_loss_fn(features, labels)
        total_loss = softmax_loss + self.alpha * centered_loss
        return total_loss, softmax_loss, centered_loss

# %% [markdown]
# ## definition of Training And Evaluation

# %%
def train(model, train_dataloader, val_dataloader, num_epochs, optimizer, patience):
    best_val_loss = np.inf
    early_stop_counter = 0
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        for images, labels in train_dataloader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            features, logits = model(images)
            total_loss, _, _ = model.compute_loss(features, logits, labels)
            total_loss.backward()
            optimizer.step()
            train_loss += total_loss.item()

        val_loss = evaluate(model, val_dataloader)
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss/len(train_dataloader)}, Val Loss: {val_loss}')

        model.centered_loss_fn.update_centers()

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0
            torch.save(model.state_dict(), '/content/drive/MyDrive/best_model_Augmented.pth')
        else:
            early_stop_counter += 1
            if early_stop_counter >= patience:
                print('Early stopping')
                break

def evaluate(model, dataloader):
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            features, logits = model(images)
            total_loss, softmax_loss, centered_loss = model.compute_loss(features, logits, labels)
            # val_loss += softmax_loss.item()
            val_loss += total_loss.item()
    return val_loss / len(dataloader)

# %% [markdown]
# ## Train

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CombinedModel(num_classes=102, alpha=0.1).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.01)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 129MB/s]

# %%
num_epochs = 10
patience = 5
train(model, train_loader, val_loader, num_epochs, optimizer, patience=patience)
# Out:
# Epoch [1/10], Train Loss: 4.324787038081401, Val Loss: 3.850708107794485
# Epoch [2/10], Train Loss: 2.984285663914036, Val Loss: 2.8428619907748316
# Epoch [3/10], Train Loss: 2.0182562434995495, Val Loss: 3.8486185458398636
# Epoch [4/10], Train Loss: 1.253940489485457, Val Loss: 1.7308079625970574
# Epoch [5/10], Train Loss: 0.7358472853093534, Val Loss: 2.4527376595363823
# Epoch [6/10], Train Loss: 0.3871783705176534, Val Loss: 1.4241070452556814
# Epoch [7/10], Train Loss: 0.20135503350882916, Val Loss: 1.5400997015737719
# Epoch [8/10], Train Loss: 0.12002784279552665, Val Loss: 1.3418752269078327
# Epoch [9/10], Train Loss: 0.07303372357745429, Val Loss: 1.332056959470113
# Epoch [10/10], Train Loss: 0.06443046675743283, Val Loss: 1.1945174355660715

# %%
# !cp /content/drive/MyDrive/best_model_Augmented.pth /content/best_model.pth

# %%
model.load_state_dict(torch.load('best_model.pth'))
# Out:
# <All keys matched successfully>

# %%
num_epochs = 10
patience = 5
train(model, train_loader, val_loader, num_epochs, optimizer, patience=patience)
# Out:
# Epoch [1/10], Train Loss: 0.044625109927477064, Val Loss: 1.1798265063634483
# Epoch [2/10], Train Loss: 0.03557626438906064, Val Loss: 1.1516736136969699
# Epoch [3/10], Train Loss: 0.02924227737695784, Val Loss: 1.0748720742681974
# Epoch [4/10], Train Loss: 0.026961176701494165, Val Loss: 1.0797935121802873
# Epoch [5/10], Train Loss: 0.02783445838738132, Val Loss: 1.0808970415464012
# Epoch [6/10], Train Loss: 0.022178296372294425, Val Loss: 1.1068893328148832
# Epoch [7/10], Train Loss: 0.019863586782200918, Val Loss: 1.0727037483005113
# Epoch [8/10], Train Loss: 0.01997136536079484, Val Loss: 1.1773188607667082
# Epoch [9/10], Train Loss: 0.01788131455714638, Val Loss: 1.1615456124787689
# Epoch [10/10], Train Loss: 0.018290864530246, Val Loss: 1.3364089778674546

# %% [markdown]
# # Test Model

# %%
# !cp /content/drive/MyDrive/best_model_Augmented.pth /content/best_model.pth

# %%
model = CombinedModel(num_classes=102, alpha=0.5).to(device)
model.load_state_dict(torch.load('best_model.pth'))
# Out:
# <All keys matched successfully>

# %%
test_loss = evaluate(model, test_loader)
print(f'Test Loss: {test_loss}')
# Out:
# Test Loss: 1.5914711264463572

# %%
torch.cuda.empty_cache()

# %%
# del train_dataset
# del train_loader

# del val_dataset
# del val_loader

# del test_dataset
# del test_loader

# %% [markdown]
# ## calculate model outputs for Test data

# %%
g_ts = []
features = []
predicts = []
with torch.no_grad():
  for images, labels in test_loader:
      images, labels = images.to(device), labels.to(device)
      res , cats = model(images)
      for g_t , predict, cat in zip(labels,res,cats):
          g_ts.append(g_t.item())
          features.append(predict.cpu())
          predicts.append(np.argmax(cat.cpu()))

# %%
import pylab
def plot_features(x,y,c):
    plt.figure(figsize=(8,8))
    pylab.scatter(x, y, c=c)
    pylab.show()

# %% [markdown]
# ## plot Feature Representation for Test data

# %%
plot_features(np.array(features)[:,0], np.array(features)[:,1], predicts)

# %%
plot_features(np.array(features)[:,2], np.array(features)[:,3], predicts)

# %%
plot_features(np.array(features)[:,4], np.array(features)[:,5], predicts)

# %%
plot_features(np.array(features)[:,6], np.array(features)[:,7], predicts)

# %%
plot_features(np.array(features)[:,8], np.array(features)[:,9], predicts)

# %% [markdown]
# ## Statistical Metrics

# %%
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
cm = confusion_matrix(np.array(g_ts), np.array(predicts), labels=[x for x in range(0,102)])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=[x for x in range(0,102)])

# %%
fig, ax = plt.subplots(figsize=(20,20))
disp.plot(ax=ax)
plt.show()

# %%
import sklearn.metrics as metrics

# %%
metrics.accuracy_score(np.array(g_ts), np.array(predicts))
# Out:
# 0.7490842490842491

# %%
metrics.precision_score(np.array(g_ts), np.array(predicts),average='micro')
# Out:
# 0.7490842490842491

# %%
metrics.precision_score(np.array(g_ts), np.array(predicts),average='macro')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.7826170163493574

# %%
metrics.f1_score(np.array(g_ts), np.array(predicts),average='micro')
# Out:
# 0.749084249084249

# %%
metrics.f1_score(np.array(g_ts), np.array(predicts),average='macro')
# Out:
# 0.7386168430791576

# %%
FP = cm.sum(axis=0) - np.diag(cm)
FN = cm.sum(axis=1) - np.diag(cm)
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)

# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Specificity or true negative rate
TNR = TN/(TN+FP)
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
# False discovery rate
FDR = FP/(TP+FP)

# Overall accuracy
ACC = (TP+TN)/(TP+FP+FN+TN)
# Out:
# <ipython-input-41-1d71f19100bf>:11: RuntimeWarning: invalid value encountered in divide
#   PPV = TP/(TP+FP)
# <ipython-input-41-1d71f19100bf>:19: RuntimeWarning: invalid value encountered in divide
#   FDR = FP/(TP+FP)

# %%
print(f'True  Positive Rate {TPR}')
# Out:
# True  Positive Rate [0.76923077 0.2962963  0.5625     1.         0.46666667 0.73333333
#  1.         1.         0.73333333 0.57142857 0.78571429 1.
#  0.72222222 0.         1.         1.         0.83333333 1.
#  0.75       0.13333333 1.         1.         0.71428571 1.
#  0.88235294 1.         0.64285714 1.         1.         0.94444444
#  0.25       0.42857143 1.         0.44444444 0.25       0.21052632
#  0.55555556 0.85       0.5        0.53333333 0.92857143 0.85714286
#  1.         1.         1.         0.64285714 0.86666667 0.78571429
#  0.83333333 0.73684211 1.         1.         0.28571429 0.58333333
#  0.6        1.         0.66666667 0.71428571 1.         1.
#  1.         0.75       1.         0.125      1.         0.41666667
#  1.         1.         0.63636364 0.84615385 0.57142857 0.92307692
#  0.95652174 0.68421053 0.17647059 1.         1.         0.75
#  0.9047619  1.         0.3        0.8        0.63636364 1.
#  0.81818182 0.21052632 1.         0.91666667 0.84210526 0.77777778
#  1.         0.78947368 0.58823529 0.5        0.875      1.
#  1.         0.6875     0.42105263 0.85714286 0.3        0.5       ]

# %%
print(f'True  Negative Rate {TNR}')
# Out:
# True  Negative Rate [1.         1.         1.         1.         0.99938386 0.99507086
#  0.99938386 0.99691358 1.         0.99814471 1.         1.
#  1.         1.         0.99323493 1.         0.99814815 1.
#  0.99690977 0.99876771 1.         1.         0.9894867  0.99382716
#  0.99383097 0.99938462 0.99815271 0.99938272 1.         1.
#  0.99753391 0.99815271 0.99569231 0.99876543 1.         0.99876467
#  0.99135802 1.         0.99320148 0.99938386 1.         0.99876847
#  0.99876543 0.99566832 0.99318463 0.99938424 0.99507086 0.99938424
#  0.99200492 1.         0.99876391 1.         1.         0.99630996
#  0.99876771 0.99815385 0.99442379 0.99137931 1.         0.99692497
#  1.         0.99814586 1.         0.99938348 0.99876999 0.98277983
#  0.99692497 1.         0.99938119 0.99507692 0.99753695 1.
#  0.99752322 0.9876467  1.         1.         0.99815951 0.99753391
#  1.         0.99691739 0.997543   0.99876391 0.99877074 1.
#  0.99692686 0.9857937  1.         1.         0.99135269 0.99876543
#  1.         0.99691167 0.99074645 1.         0.99445129 0.99876619
#  0.99631223 1.         1.         0.9932266  0.99570025 0.99691358]

# %%
print(f'False Positive Rate {FPR}')
# Out:
# False Positive Rate [0.         0.         0.         0.         0.00061614 0.00492914
#  0.00061614 0.00308642 0.         0.00185529 0.         0.
#  0.         0.         0.00676507 0.         0.00185185 0.
#  0.00309023 0.00123229 0.         0.         0.0105133  0.00617284
#  0.00616903 0.00061538 0.00184729 0.00061728 0.         0.
#  0.00246609 0.00184729 0.00430769 0.00123457 0.         0.00123533
#  0.00864198 0.         0.00679852 0.00061614 0.         0.00123153
#  0.00123457 0.00433168 0.00681537 0.00061576 0.00492914 0.00061576
#  0.00799508 0.         0.00123609 0.         0.         0.00369004
#  0.00123229 0.00184615 0.00557621 0.00862069 0.         0.00307503
#  0.         0.00185414 0.         0.00061652 0.00123001 0.01722017
#  0.00307503 0.         0.00061881 0.00492308 0.00246305 0.
#  0.00247678 0.0123533  0.         0.         0.00184049 0.00246609
#  0.         0.00308261 0.002457   0.00123609 0.00122926 0.
#  0.00307314 0.0142063  0.         0.         0.00864731 0.00123457
#  0.         0.00308833 0.00925355 0.         0.00554871 0.00123381
#  0.00368777 0.         0.         0.0067734  0.00429975 0.00308642]

# %%
print(f'False Negative Rate {FNR}')
# Out:
# False Negative Rate [0.23076923 0.7037037  0.4375     0.         0.53333333 0.26666667
#  0.         0.         0.26666667 0.42857143 0.21428571 0.
#  0.27777778 1.         0.         0.         0.16666667 0.
#  0.25       0.86666667 0.         0.         0.28571429 0.
#  0.11764706 0.         0.35714286 0.         0.         0.05555556
#  0.75       0.57142857 0.         0.55555556 0.75       0.78947368
#  0.44444444 0.15       0.5        0.46666667 0.07142857 0.14285714
#  0.         0.         0.         0.35714286 0.13333333 0.21428571
#  0.16666667 0.26315789 0.         0.         0.71428571 0.41666667
#  0.4        0.         0.33333333 0.28571429 0.         0.
#  0.         0.25       0.         0.875      0.         0.58333333
#  0.         0.         0.36363636 0.15384615 0.42857143 0.07692308
#  0.04347826 0.31578947 0.82352941 0.         0.         0.25
#  0.0952381  0.         0.7        0.2        0.36363636 0.
#  0.18181818 0.78947368 0.         0.08333333 0.15789474 0.22222222
#  0.         0.21052632 0.41176471 0.5        0.125      0.
#  0.         0.3125     0.57894737 0.14285714 0.7        0.5       ]

# %% [markdown]
# # Pair Similarity

# %%
from itertools import combinations
from sklearn.metrics.pairwise import cosine_similarity

# %%
# features : n dimension representation of each image
# g_ts : real labels

# %% [markdown]
# ## Create Pair Samples

# %%
features = np.array(features)
g_ts = np.array(g_ts)
g_ts = g_ts.reshape(g_ts.shape[0],1)

# %%
features_category = np.concatenate((features, g_ts), axis=-1)

# %%
features_category.shape
# Out:
# (1638, 11)

# %%
features_category = list(combinations(features_category, 2))

# %%
features_category[0]
# Out:
# (array([ 0.91247696, -1.18915975, -0.05828862, -0.81519186,  2.0917747 ,
#         -2.29175091, -1.5192771 ,  0.28449026,  1.47348106,  0.97611749,
#         30.        ]),
#  array([ 1.10045755,  0.49169242,  0.21499851, -1.77036238,  0.80749071,
#         -1.15264845, -1.92495513,  0.9246645 ,  0.60957205, -0.56465745,
#         43.        ]))

# %%
total_pairs = len(features_category)
total_pairs
# Out:
# 1340703

# %% [markdown]
# ## calculate cosine similarity

# %%
Y_true = []
cosine_sim = []
for pair in features_category:
    d1,d2 = pair
    Y_true.append(d1[-1] == d2[-1])
    dd1 = np.array(d1[:features_dim]).reshape((1,features_dim))
    dd2 = np.array(d2[:features_dim]).reshape((1,features_dim))
    cosine_sim.append(cosine_similarity(dd1,dd2))

# %%
np.count_nonzero(np.array(Y_true) == 1) # Actual True in Pairs
# Out:
# 13047

# %%
cosine_sim = np.array(cosine_sim).flatten()

# %%
false_positive_rate, true_positive_rate, threshold = metrics.roc_curve(np.array(Y_true),np.array(cosine_sim))

# %%
plt.subplots(1, figsize=(10,10))
plt.plot(threshold, false_positive_rate)
plt.plot(threshold, true_positive_rate)
plt.xlabel('Threshold')
plt.ylabel('Rate')
plt.legend(['Flase Positive', 'True Positive'])
plt.show()

# %%
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_predictions(np.array(Y_true),np.array(cosine_sim))
